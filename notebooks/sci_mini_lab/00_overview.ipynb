# %% [markdown]
# # SciPy MiniLab
#
# Problem:
# Numerical optimization and statistical estimation
#
# Goal:
# Understand SciPy as a numerical backend for AI models
#
# Modules:
# scipy.optimize, scipy.stats, scipy.linalg
